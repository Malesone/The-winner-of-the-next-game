# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# Molto utile
# https://stackabuse.com/python-for-nlp-tokenization-stemming-and-lemmatization-with-spacy-library/

# %%
import urllib.request
import json
import spacy
nlp = spacy.load("en_core_web_sm")

tokenize = lambda text: [x.lemma_.lower() for x in text if x.pos_ in ['NOUN', 'PROPN', 'VERB', 'ADJ', 'ADV']]

# %%
dataframe = pd.read_csv("completati/description_predictions.csv", index_col=0)
#for k, value in dataframe.iterrows():
#    value.description
match = dataframe.iloc[:1]
match = match.iloc[:1]

desc = match.description.values[0]

# %%
my_doc = nlp(desc)

# %%
from spacy import displacy 
displacy.render(my_doc, style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="47005c65b92e4b918d9a047cd9f4e644-0" class="displacy" width="28225" height="1449.5" direction="ltr" style="max-width: none; height: 1449.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1359.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Verona</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1359.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1359.5">
# ...
